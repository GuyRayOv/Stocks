# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import warnings
import pickle
import os
from sklearn import metrics
import seaborn as sb
import matplotlib.pyplot as plt
import json
from google.colab import drive
from google.colab import files
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Bootstrap

# %%
import os
from dotenv import load_dotenv

# Find and load the .env file from the current or parent directories
load_dotenv()

# Access the environment variable using os.getenv()
PROJECT_PATH = os.getenv('PROJECT_PATH')
CONFIG_FILE = f"{PROJECT_PATH}/src/config.json"

# %%
drive.mount('/content/drive')

with open(CONFIG_FILE, 'r') as f:
    project_config = json.load(f)
    project_config.pop('_comment', None)
    project_config.pop('_note', None)
    f.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1614198415.py in <cell line: 0>()
#       1 drive.mount('/content/drive')
#       2
# ----> 3 with open(CONFIG_FILE, 'r') as f:
#       4     project_config = json.load(f)
#       5     project_config.pop('_comment', None)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Projects/GitHub/Spo/src/config.json'

# %%
np.random.seed(31071967)

# %% [markdown]
# # Senity check

# %%
for item in project_config:
    print(f"{item} = {project_config[item]}")

# %% [markdown]
# # Start Notebook
#
# ---
